# %% [markdown]
# <a href="https://colab.research.google.com/github/SRAVANIDHARA/FARO_assignment/blob/master/Pointnet_Training_and_Evaluate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup HyperOpt

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.17.5)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.28.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.1)

# %% [markdown]
# ## Running pointnet
#
# Mount the google drive and point to the folder containing the train.py and run the code from there with a slight modification.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')

# %%
#!ls
# !python train.py --max_epoch=4 --run_mode='hyperopt' --log_dir="log/hyperopt" --max_evals=2 --max_trials=2
# Out:
# Log dir:log/hyperopt already exists! creating a new one.
# New log dir:log/hyperopt/6
# 1:Starting the run with the mode:hyperopt
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/hyperopt', max_epoch=4, max_evals=2, max_trials=2, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='hyperopt', trials_path='')
#
# Starting hyperopt
# HyperOpt batch size selected:8
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-15 20:55:20.685694: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-03-15 20:55:20.690623: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-03-15 20:55:20.690818: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1613100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 20:55:20.690862: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-15 20:55:20.692547: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-15 20:55:20.786324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 20:55:20.786912: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x16132c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 20:55:20.786950: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-03-15 20:55:20.787125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 20:55:20.787566: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 20:55:20.787858: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 20:55:20.789178: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 20:55:20.790588: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 20:55:20.790925: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 20:55:20.792223: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 20:55:20.792895: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 20:55:20.795643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 20:55:20.795760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 20:55:20.796156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 20:55:20.796519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 20:55:20.796595: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 20:55:20.797579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 20:55:20.797608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 20:55:20.797621: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 20:55:20.797741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 20:55:20.798134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 20:55:20.798518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-15 20:55:21.268907: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
#   0% 0/2 [00:05<?, ?it/s, best loss: ?]2020-03-15 20:55:23.649405: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 20:55:23.928047: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.805999
# accuracy: 0.154297
# ----1-----
# mean loss: 3.202027
# accuracy: 0.180664
# ----2-----
# mean loss: 2.971080
# accuracy: 0.220215
# ----3-----
# mean loss: 2.862407
# accuracy: 0.231796
# ----4-----
# mean loss: 2.810336
# accuracy: 0.250488
# ----0-----
# ----1-----
# eval mean loss: 2.451796
# eval accuracy: 0.303166
# eval avg class acc: 0.225982
# --- Total running time for EPOCH 000 : 0:02:14.918597 ---
# Model saved in file: log/hyperopt/6/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.571340
# accuracy: 0.272461
# ----1-----
# mean loss: 2.314495
# accuracy: 0.343262
# ----2-----
# mean loss: 2.147606
# accuracy: 0.379854
# ----3-----
# mean loss: 1.964592
# accuracy: 0.444336
# ----4-----
# mean loss: 1.870073
# accuracy: 0.446289
# ----0-----
# ----1-----
# eval mean loss: 1.859626
# eval accuracy: 0.509334
# eval avg class acc: 0.426612
# --- Total running time for EPOCH 001 : 0:02:12.297439 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 1.805775
# accuracy: 0.475098
# ----1-----
# mean loss: 1.747281
# accuracy: 0.500000
# ----2-----
# mean loss: 1.758893
# accuracy: 0.486328
# ----3-----
# mean loss: 1.598908
# accuracy: 0.510922
# ----4-----
# mean loss: 1.632308
# accuracy: 0.522461
# ----0-----
# ----1-----
# eval mean loss: 1.395812
# eval accuracy: 0.577922
# eval avg class acc: 0.498221
# --- Total running time for EPOCH 002 : 0:02:12.429500 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.535450
# accuracy: 0.533691
# ----1-----
# mean loss: 1.430567
# accuracy: 0.567354
# ----2-----
# mean loss: 1.396341
# accuracy: 0.577148
# ----3-----
# mean loss: 1.372383
# accuracy: 0.589844
# ----4-----
# mean loss: 1.336018
# accuracy: 0.604492
# ----0-----
# ----1-----
# eval mean loss: 1.168130
# eval accuracy: 0.647727
# eval avg class acc: 0.565303
# --- Total running time for EPOCH 003 : 0:02:12.515594 ---
# --- Total running time for MAIN : 0:08:58.078609 ---
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [08:58<08:58, 538.09s/it, best loss: 1.168130378637995]2020-03-15 21:04:18.117993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:04:18.118440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:04:18.118559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:04:18.118591: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:04:18.118621: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:04:18.118646: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:04:18.118666: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:04:18.118686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:04:18.118711: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:04:18.118794: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:04:18.119145: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:04:18.119452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:04:18.119562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:04:18.119578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:04:18.119587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:04:18.119702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:04:18.120066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:04:18.120394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 21:04:18.639347: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.859655
# accuracy: 0.191406
# ----1-----
# mean loss: 2.827049
# accuracy: 0.326660
# ----2-----
# mean loss: 2.467709
# accuracy: 0.356445
# ----3-----
# mean loss: 2.216648
# accuracy: 0.391113
# ----4-----
# mean loss: 1.953787
# accuracy: 0.465074
# ----0-----
# ----1-----
# eval mean loss: 1.856799
# eval accuracy: 0.469156
# eval avg class acc: 0.398678
# --- Total running time for EPOCH 000 : 0:02:01.803488 ---
# Model saved in file: log/hyperopt/6/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.820157
# accuracy: 0.491211
# ----1-----
# mean loss: 1.851035
# accuracy: 0.484375
# ----2-----
# mean loss: 1.696915
# accuracy: 0.512695
# ----3-----
# mean loss: 1.587759
# accuracy: 0.541992
# ----4-----
# mean loss: 1.377183
# accuracy: 0.593750
# ----0-----
# ----1-----
# eval mean loss: 1.499525
# eval accuracy: 0.540990
# eval avg class acc: 0.489454
# --- Total running time for EPOCH 001 : 0:02:00.390358 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 2.528196
# accuracy: 0.432129
# ----1-----
# mean loss: 1.882679
# accuracy: 0.434570
# ----2-----
# mean loss: 1.659551
# accuracy: 0.486816
# ----3-----
# mean loss: 1.509071
# accuracy: 0.543945
# ----4-----
# mean loss: 1.412207
# accuracy: 0.568015
# ----0-----
# ----1-----
# eval mean loss: 1.348498
# eval accuracy: 0.594968
# eval avg class acc: 0.518334
# --- Total running time for EPOCH 002 : 0:02:00.244042 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.342456
# accuracy: 0.581055
# ----1-----
# mean loss: 1.319819
# accuracy: 0.601562
# ----2-----
# mean loss: 1.268014
# accuracy: 0.600098
# ----3-----
# mean loss: 1.237255
# accuracy: 0.625000
# ----4-----
# mean loss: 1.131651
# accuracy: 0.654412
# ----0-----
# ----1-----
# eval mean loss: 1.052945
# eval accuracy: 0.684659
# eval avg class acc: 0.594956
# --- Total running time for EPOCH 003 : 0:02:00.149401 ---
# --- Total running time for MAIN : 0:08:07.175080 ---
# 100% 2/2 [17:05<00:00, 522.82s/it, best loss: 1.052945263587035]
# Run 1 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.168130378637995, 'status': 'ok', 'accuracy': 0.6477272727272727, 'avg_class_accuracy': 0.5653029715762273, 'eval_time': 1584306255.0406764, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 20, 55, 16, 994000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 4, 15, 83000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.052945263587035, 'status': 'ok', 'accuracy': 0.6846590909090909, 'avg_class_accuracy': 0.5949556384921835, 'eval_time': 1584306742.2240114, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 4, 15, 85000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 12, 22, 271000)}
# Written trials on run 1.
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-15 21:12:25.457970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:12:25.458387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:12:25.458483: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:12:25.458512: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:12:25.458537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:12:25.458561: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:12:25.458585: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:12:25.458607: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:12:25.458631: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:12:25.458721: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:12:25.459150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:12:25.459474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:12:25.459524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:12:25.459541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:12:25.459556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:12:25.459656: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:12:25.460008: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:12:25.460323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 21:12:26.005823: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.793438
# accuracy: 0.205078
# ----1-----
# mean loss: 2.729975
# accuracy: 0.333008
# ----2-----
# mean loss: 2.401932
# accuracy: 0.375488
# ----3-----
# mean loss: 1.957951
# accuracy: 0.474265
# ----4-----
# mean loss: 1.991893
# accuracy: 0.459473
# ----0-----
# ----1-----
# eval mean loss: 1.729973
# eval accuracy: 0.532873
# eval avg class acc: 0.426779
# --- Total running time for EPOCH 000 : 0:02:01.752628 ---
# Model saved in file: log/hyperopt/6/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.688367
# accuracy: 0.525391
# ----1-----
# mean loss: 1.812941
# accuracy: 0.532715
# ----2-----
# mean loss: 1.975227
# accuracy: 0.451172
# ----3-----
# mean loss: 1.601461
# accuracy: 0.532715
# ----4-----
# mean loss: 1.402525
# accuracy: 0.576593
# ----0-----
# ----1-----
# eval mean loss: 1.205658
# eval accuracy: 0.647321
# eval avg class acc: 0.529894
# --- Total running time for EPOCH 001 : 0:02:00.098573 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 1.327892
# accuracy: 0.617188
# ----1-----
# mean loss: 1.259967
# accuracy: 0.631127
# ----2-----
# mean loss: 1.288959
# accuracy: 0.613770
# ----3-----
# mean loss: 1.180435
# accuracy: 0.651855
# ----4-----
# mean loss: 1.244228
# accuracy: 0.633789
# ----0-----
# ----1-----
# eval mean loss: 1.141451
# eval accuracy: 0.670455
# eval avg class acc: 0.580505
# --- Total running time for EPOCH 002 : 0:02:00.048075 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.134217
# accuracy: 0.658691
# ----1-----
# mean loss: 1.128271
# accuracy: 0.664551
# ----2-----
# mean loss: 1.078276
# accuracy: 0.693359
# ----3-----
# mean loss: 1.026855
# accuracy: 0.699707
# ----4-----
# mean loss: 1.029437
# accuracy: 0.688725
# ----0-----
# ----1-----
# eval mean loss: 1.012377
# eval accuracy: 0.703734
# eval avg class acc: 0.627487
# --- Total running time for EPOCH 003 : 0:02:00.010068 ---
# --- Total running time for MAIN : 0:08:06.772103 ---
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [08:06<08:06, 486.80s/it, best loss: 1.012377003957699]2020-03-15 21:20:32.013662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:20:32.014029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:20:32.014130: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:20:32.014151: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:20:32.014171: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:20:32.014187: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:20:32.014202: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:20:32.014217: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:20:32.014233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:20:32.014319: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:20:32.014657: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:20:32.014934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:20:32.015375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:20:32.015411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:20:32.015425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:20:32.015593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:20:32.015991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:20:32.016289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 21:20:32.700916: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.813084
# accuracy: 0.222426
# ----1-----
# mean loss: 2.869365
# accuracy: 0.326172
# ----2-----
# mean loss: 2.488893
# accuracy: 0.365234
# ----3-----
# mean loss: 2.054513
# accuracy: 0.445801
# ----4-----
# mean loss: 1.871746
# accuracy: 0.479980
# ----0-----
# ----1-----
# eval mean loss: 1.813653
# eval accuracy: 0.494318
# eval avg class acc: 0.435788
# --- Total running time for EPOCH 000 : 0:02:01.904780 ---
# Model saved in file: log/hyperopt/6/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.799395
# accuracy: 0.501465
# ----1-----
# mean loss: 1.573240
# accuracy: 0.560049
# ----2-----
# mean loss: 1.453644
# accuracy: 0.584961
# ----3-----
# mean loss: 1.423972
# accuracy: 0.602539
# ----4-----
# mean loss: 1.409948
# accuracy: 0.594238
# ----0-----
# ----1-----
# eval mean loss: 1.138937
# eval accuracy: 0.669643
# eval avg class acc: 0.582538
# --- Total running time for EPOCH 001 : 0:02:00.211861 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 1.271508
# accuracy: 0.629883
# ----1-----
# mean loss: 1.266876
# accuracy: 0.613358
# ----2-----
# mean loss: 1.247961
# accuracy: 0.634766
# ----3-----
# mean loss: 1.200922
# accuracy: 0.655273
# ----4-----
# mean loss: 1.164048
# accuracy: 0.655762
# ----0-----
# ----1-----
# eval mean loss: 1.123752
# eval accuracy: 0.653815
# eval avg class acc: 0.586038
# --- Total running time for EPOCH 002 : 0:02:00.201256 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.130107
# accuracy: 0.671875
# ----1-----
# mean loss: 1.066058
# accuracy: 0.669730
# ----2-----
# mean loss: 1.064651
# accuracy: 0.681152
# ----3-----
# mean loss: 1.067497
# accuracy: 0.683594
# ----4-----
# mean loss: 1.031845
# accuracy: 0.686035
# ----0-----
# ----1-----
# eval mean loss: 0.965031
# eval accuracy: 0.709416
# eval avg class acc: 0.646021
# --- Total running time for EPOCH 003 : 0:02:00.189838 ---
# --- Total running time for MAIN : 0:08:07.364023 ---
# 100% 2/2 [16:14<00:00, 486.98s/it, best loss: 0.9650310781094935]
# Run 2 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.168130378637995, 'status': 'ok', 'accuracy': 0.6477272727272727, 'avg_class_accuracy': 0.5653029715762273, 'eval_time': 1584306255.0406764, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 20, 55, 16, 994000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 4, 15, 83000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.052945263587035, 'status': 'ok', 'accuracy': 0.6846590909090909, 'avg_class_accuracy': 0.5949556384921835, 'eval_time': 1584306742.2240114, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 4, 15, 85000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 12, 22, 271000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.012377003957699, 'status': 'ok', 'accuracy': 0.7037337662337663, 'avg_class_accuracy': 0.6274866558321708, 'eval_time': 1584307229.0196905, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 12, 22, 282000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 20, 29, 81000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 0.9650310781094935, 'status': 'ok', 'accuracy': 0.7094155844155844, 'avg_class_accuracy': 0.6460209259179359, 'eval_time': 1584307716.4184864, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 20, 29, 83000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 28, 36, 465000)}
# Written trials on run 2.

# %%
import os
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')
#!ls
# !python train.py --max_epoch=2 --run_mode='normal' --log_dir="log/normal32" --batch_size=32
#--max_evals=5  --max_trials=10
# Out:
# Log dir:log/normal32 already exists! creating a new one.
# New log dir:log/normal32/5
# 1:Starting the run with the mode:normal
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/normal32', max_epoch=2, max_evals=1, max_trials=10, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='normal', trials_path='')
#
# Starting normal run
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
# WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-15 21:28:53.261691: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-03-15 21:28:53.266187: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-03-15 21:28:53.266393: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1ba3100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 21:28:53.266422: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-15 21:28:53.268232: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-15 21:28:53.378791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:28:53.379346: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1ba32c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 21:28:53.379375: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-03-15 21:28:53.379536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:28:53.379868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:28:53.380137: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:28:53.381647: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:28:53.383074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:28:53.383401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:28:53.384656: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:28:53.385307: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:28:53.388017: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:28:53.388119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:28:53.388514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:28:53.388816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:28:53.388866: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:28:53.389844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:28:53.389866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:28:53.389876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:28:53.389969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:28:53.390366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:28:53.390715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-15 21:28:53.824347: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# 2020-03-15 21:28:56.287846: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:28:56.556850: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.793251
# accuracy: 0.176758
# ----1-----
# mean loss: 2.710273
# accuracy: 0.325980
# ----2-----
# mean loss: 2.317028
# accuracy: 0.415039
# ----3-----
# mean loss: 2.027696
# accuracy: 0.451172
# ----4-----
# mean loss: 1.920438
# accuracy: 0.471191
# ----0-----
# ----1-----
# eval mean loss: 1.751251
# eval accuracy: 0.501218
# eval avg class acc: 0.436778
# --- Total running time for EPOCH 000 : 0:02:02.631947 ---
# Model saved in file: log/normal32/5/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.718633
# accuracy: 0.525735
# ----1-----
# mean loss: 1.591717
# accuracy: 0.542969
# ----2-----
# mean loss: 1.514091
# accuracy: 0.567871
# ----3-----
# mean loss: 1.514604
# accuracy: 0.561035
# ----4-----
# mean loss: 1.409821
# accuracy: 0.590332
# ----0-----
# ----1-----
# eval mean loss: 1.282367
# eval accuracy: 0.625000
# eval avg class acc: 0.564930
# --- Total running time for EPOCH 001 : 0:01:59.749457 ---
# --- Total running time for MAIN : 0:04:08.247835 ---

# %%
import os
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')
#!ls
# !python train.py --max_epoch=2 --run_mode='normal' --log_dir="log/normal16" --batch_size=16
#--max_evals=5  --max_trials=10
# Out:
# Log dir:log/normal16 already exists! creating a new one.
# New log dir:log/normal16/3
# 1:Starting the run with the mode:normal
# Namespace(batch_size=16, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/normal16', max_epoch=2, max_evals=1, max_trials=10, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='normal', trials_path='')
#
# Starting normal run
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
# WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-15 21:33:14.501136: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-03-15 21:33:14.506236: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-03-15 21:33:14.506455: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3035100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 21:33:14.506485: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-15 21:33:14.508316: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-15 21:33:14.619359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:33:14.619900: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x30352c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 21:33:14.619929: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-03-15 21:33:14.620074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:33:14.620425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:33:14.620702: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:33:14.621989: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:33:14.623437: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:33:14.623740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:33:14.625058: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:33:14.625692: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:33:14.628360: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:33:14.628465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:33:14.628843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:33:14.629156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:33:14.629215: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:33:14.630223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:33:14.630250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:33:14.630260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:33:14.630392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:33:14.630755: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:33:14.631087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-15 21:33:15.075519: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# 2020-03-15 21:33:17.371430: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:33:17.632589: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.800898
# accuracy: 0.176758
# ----1-----
# mean loss: 2.921832
# accuracy: 0.267578
# ----2-----
# mean loss: 2.628623
# accuracy: 0.296875
# ----3-----
# mean loss: 2.284354
# accuracy: 0.368325
# ----4-----
# mean loss: 2.136407
# accuracy: 0.404785
# ----0-----
# ----1-----
# eval mean loss: 1.975337
# eval accuracy: 0.429383
# eval avg class acc: 0.333811
# --- Total running time for EPOCH 000 : 0:01:59.798630 ---
# Model saved in file: log/normal16/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.008503
# accuracy: 0.417969
# ----1-----
# mean loss: 1.839629
# accuracy: 0.462891
# ----2-----
# mean loss: 1.822630
# accuracy: 0.455566
# ----3-----
# mean loss: 1.677673
# accuracy: 0.498786
# ----4-----
# mean loss: 1.584695
# accuracy: 0.523438
# ----0-----
# ----1-----
# eval mean loss: 1.706432
# eval accuracy: 0.475649
# eval avg class acc: 0.418439
# --- Total running time for EPOCH 001 : 0:01:57.149013 ---
# --- Total running time for MAIN : 0:04:02.580106 ---

# %%
import os
#os.chdir('/content/drive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/')


# !python train.py --max_epoch=2 --run_mode='hyperopt' --log_dir="log/hyperopt88" --max_evals=2  --max_trials=2
# --batch_size=16 #--log_dir="log"
# Out:
# 1:Starting the run with the mode:hyperopt
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/hyperopt88', max_epoch=2, max_evals=2, max_trials=2, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='hyperopt', trials_path='')
#
# Starting hyperopt
# HyperOpt batch size selected:8
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-15 21:39:01.300392: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-03-15 21:39:01.304984: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-03-15 21:39:01.305181: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1919100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 21:39:01.305213: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-15 21:39:01.307042: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-15 21:39:01.422342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:39:01.422938: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19192c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 21:39:01.422974: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-03-15 21:39:01.423140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:39:01.423528: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:39:01.423872: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:39:01.425373: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:39:01.426846: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:39:01.427188: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:39:01.428648: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:39:01.429346: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:39:01.432420: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:39:01.432529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:39:01.432925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:39:01.433240: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:39:01.433327: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:39:01.434333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:39:01.434363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:39:01.434376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:39:01.434495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:39:01.434894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:39:01.435250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-15 21:39:01.867033: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
#   0% 0/2 [00:05<?, ?it/s, best loss: ?]2020-03-15 21:39:04.116664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:39:04.398615: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.972580
# accuracy: 0.125607
# ----1-----
# mean loss: 3.291664
# accuracy: 0.163086
# ----2-----
# mean loss: 3.021464
# accuracy: 0.216797
# ----3-----
# mean loss: 2.863584
# accuracy: 0.250488
# ----4-----
# mean loss: 2.717827
# accuracy: 0.250977
# ----0-----
# ----1-----
# eval mean loss: 2.432546
# eval accuracy: 0.307630
# eval avg class acc: 0.214013
# --- Total running time for EPOCH 000 : 0:02:14.784081 ---
# Model saved in file: log/hyperopt88/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.518660
# accuracy: 0.292480
# ----1-----
# mean loss: 2.345162
# accuracy: 0.345703
# ----2-----
# mean loss: 2.174919
# accuracy: 0.384766
# ----3-----
# mean loss: 2.026949
# accuracy: 0.407227
# ----4-----
# mean loss: 1.915423
# accuracy: 0.427184
# ----0-----
# ----1-----
# eval mean loss: 1.673383
# eval accuracy: 0.501218
# eval avg class acc: 0.411874
# --- Total running time for EPOCH 001 : 0:02:12.138436 ---
# --- Total running time for MAIN : 0:04:32.612542 ---
# HyperOpt batch size selected:8
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [04:32<04:32, 272.63s/it, best loss: 1.6733828939787754]2020-03-15 21:43:33.290702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:43:33.291080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:43:33.291195: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:43:33.291216: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:43:33.291233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:43:33.291249: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:43:33.291262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:43:33.291296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:43:33.291334: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:43:33.291409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:43:33.291737: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:43:33.292019: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:43:33.292060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:43:33.292069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:43:33.292078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:43:33.292149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:43:33.292479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:43:33.292769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 21:43:33.792712: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.952050
# accuracy: 0.135922
# ----1-----
# mean loss: 3.277751
# accuracy: 0.172363
# ----2-----
# mean loss: 3.014238
# accuracy: 0.210938
# ----3-----
# mean loss: 2.817684
# accuracy: 0.245117
# ----4-----
# mean loss: 2.640838
# accuracy: 0.289062
# ----0-----
# ----1-----
# eval mean loss: 2.372192
# eval accuracy: 0.300731
# eval avg class acc: 0.232164
# --- Total running time for EPOCH 000 : 0:02:13.951503 ---
# Model saved in file: log/hyperopt88/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.493772
# accuracy: 0.304612
# ----1-----
# mean loss: 2.317722
# accuracy: 0.337402
# ----2-----
# mean loss: 2.203990
# accuracy: 0.366699
# ----3-----
# mean loss: 2.063056
# accuracy: 0.414062
# ----4-----
# mean loss: 1.997361
# accuracy: 0.408203
# ----0-----
# ----1-----
# eval mean loss: 1.955488
# eval accuracy: 0.413555
# eval avg class acc: 0.335773
# --- Total running time for EPOCH 001 : 0:02:12.589870 ---
# --- Total running time for MAIN : 0:04:31.133525 ---
# 100% 2/2 [09:03<00:00, 272.18s/it, best loss: 1.6733828939787754]
# Run 1 - Best param found:{'batch_size': 2}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.6733828939787754, 'status': 'ok', 'accuracy': 0.5012175324675324, 'avg_class_accuracy': 0.4118736199201315, 'eval_time': 1584308610.299919, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 38, 57, 716000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 43, 30, 342000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.955488206117184, 'status': 'ok', 'accuracy': 0.4135551948051948, 'avg_class_accuracy': 0.3357732270498051, 'eval_time': 1584308881.4433258, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 43, 30, 344000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 48, 1, 488000)}
# Written trials on run 1.
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-15 21:48:04.534810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:48:04.535220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:48:04.535348: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:48:04.535382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:48:04.535412: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:48:04.535436: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:48:04.535459: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:48:04.535485: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:48:04.535513: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:48:04.535604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:48:04.535984: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:48:04.536311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:48:04.536361: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:48:04.536385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:48:04.536398: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:48:04.536498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:48:04.536865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:48:04.537185: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 21:48:05.069476: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.779980
# accuracy: 0.180176
# ----1-----
# mean loss: 2.966603
# accuracy: 0.244629
# ----2-----
# mean loss: 2.638424
# accuracy: 0.305176
# ----3-----
# mean loss: 2.329403
# accuracy: 0.353027
# ----4-----
# mean loss: 2.214091
# accuracy: 0.390170
# ----0-----
# ----1-----
# eval mean loss: 2.253646
# eval accuracy: 0.347808
# eval avg class acc: 0.262853
# --- Total running time for EPOCH 000 : 0:01:59.009995 ---
# Model saved in file: log/hyperopt88/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.047359
# accuracy: 0.412621
# ----1-----
# mean loss: 2.030178
# accuracy: 0.411621
# ----2-----
# mean loss: 1.876137
# accuracy: 0.459961
# ----3-----
# mean loss: 1.830816
# accuracy: 0.468262
# ----4-----
# mean loss: 1.734017
# accuracy: 0.493164
# ----0-----
# ----1-----
# eval mean loss: 1.367151
# eval accuracy: 0.595779
# eval avg class acc: 0.484253
# --- Total running time for EPOCH 001 : 0:01:57.374109 ---
# --- Total running time for MAIN : 0:04:01.121624 ---
# HyperOpt batch size selected:2
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [04:01<04:01, 241.14s/it, best loss: 1.3671512886301262]2020-03-15 21:52:05.836145: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:52:05.836551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 21:52:05.836653: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 21:52:05.836674: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 21:52:05.836697: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 21:52:05.836714: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 21:52:05.836728: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 21:52:05.836743: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 21:52:05.836759: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 21:52:05.836833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:52:05.837156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:52:05.837445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 21:52:05.837541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 21:52:05.837552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 21:52:05.837561: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 21:52:05.837643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:52:05.837974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 21:52:05.838265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 21:52:06.481465: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 6.784040
# accuracy: 0.073730
# ----1-----
# mean loss: 4.586517
# accuracy: 0.074029
# ----2-----
# mean loss: 4.012251
# accuracy: 0.079590
# ----3-----
# mean loss: 4.642573
# accuracy: 0.067871
# ----4-----
# mean loss: 3.587704
# accuracy: 0.074219
# ----0-----
# ----1-----
# eval mean loss: 59219.359199
# eval accuracy: 0.036062
# eval avg class acc: 0.022250
# --- Total running time for EPOCH 000 : 0:03:13.717280 ---
# Model saved in file: log/hyperopt88/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.737781
# accuracy: 0.083496
# ----1-----
# mean loss: 3.818499
# accuracy: 0.077148
# ----2-----
# mean loss: 3.557405
# accuracy: 0.094053
# ----3-----
# mean loss: 3.456403
# accuracy: 0.103516
# ----4-----
# mean loss: 3.479367
# accuracy: 0.107910
# ----0-----
# ----1-----
# eval mean loss: 71061.476450
# eval accuracy: 0.039708
# eval avg class acc: 0.024500
# --- Total running time for EPOCH 001 : 0:03:13.623244 ---
# --- Total running time for MAIN : 0:06:32.248541 ---
# 100% 2/2 [10:33<00:00, 286.47s/it, best loss: 1.3671512886301262]
# Run 2 - Best param found:{'batch_size': 3}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.6733828939787754, 'status': 'ok', 'accuracy': 0.5012175324675324, 'avg_class_accuracy': 0.4118736199201315, 'eval_time': 1584308610.299919, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 38, 57, 716000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 43, 30, 342000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.955488206117184, 'status': 'ok', 'accuracy': 0.4135551948051948, 'avg_class_accuracy': 0.3357732270498051, 'eval_time': 1584308881.4433258, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 43, 30, 344000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 48, 1, 488000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.3671512886301262, 'status': 'ok', 'accuracy': 0.5957792207792207, 'avg_class_accuracy': 0.4842525935673777, 'eval_time': 1584309122.6054902, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 48, 1, 519000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 52, 2, 652000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 71061.47645037294, 'status': 'ok', 'accuracy': 0.03970826580226904, 'avg_class_accuracy': 0.0245, 'eval_time': 1584309514.8693147, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 21, 52, 2, 654000), 'refresh_time': datetime.datetime(2020, 3, 15, 21, 58, 34, 915000)}
# Written trials on run 2.

# %%
#os.chdir('/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet/log/hyperopt')
#!pip install --upgrade hyperopt
#from __future__ import absolute_import
import os
import pickle
from hyperopt import Trials
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/log/hyperopt/1')
# !ls

trials = Trials()
LOG_DIR = ""
trialFilePath = os.path.join(LOG_DIR, "trials.p")
if os.path.exists(trialFilePath):
    trials = pickle.load(open(trialFilePath, "rb"))
    print ("Trials loaded.")

import json
import pickle
#WRITER = open("test.txt", "wb")
for trial in trials.results:
    print (trial)

print (trials.idxs_vals[0])
  
import pandas as pd
# Dataframe of results from optimization
tpe_results = pd.DataFrame({'batch size': [x['RunParams']['batch_size'] for x in trials.results],
                            'loss': [x['loss'] for x in trials.results],
                            'accuracy': [x['accuracy'] for x in trials.results] 
                            })
                            
tpe_results.head()
# Out:
# checkpoint     model.ckpt.data-00000-of-00001  model.ckpt.meta	test   train.py
# log_train.txt  model.ckpt.index		       pointnet_cls.py	train  trials.p
# Trials loaded.
# {'loss': 1.160251766249731, 'status': 'ok', 'accuracy': 0.6554383116883117, 'avg_class_accuracy': 0.5793263484393052, 'eval_time': 1583753076.3301764, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'loss': 1.3395599972505075, 'status': 'ok', 'accuracy': 0.5949675324675324, 'avg_class_accuracy': 0.5010895751535287, 'eval_time': 1583753775.2543623, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'loss': 1.229252468649443, 'status': 'ok', 'accuracy': 0.6282467532467533, 'avg_class_accuracy': 0.5495627417986222, 'eval_time': 1583754428.544316, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'loss': 1.4733369370753115, 'status': 'ok', 'accuracy': 0.6026785714285714, 'avg_class_accuracy': 0.5212600650549155, 'eval_time': 1583755111.6566696, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'batch_size': [0, 1, 2, 3]}
#    batch size      loss  accuracy
# 0          16  1.160252  0.655438
# 1           8  1.339560  0.594968
# 2          16  1.229252  0.628247
# 3           8  1.473337  0.602679

# %%
import os
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')

#second run since first run was interrupted at EPOCH 119
# !python train.py --max_epoch=2 --run_mode='hyperopt' --log_dir="log/hyperopttiny" --max_eval=2  # --batch_size=16 #--log_dir="log"
# Out:
# 1:Starting the run with the mode:hyperopt
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/hyperopttiny', max_epoch=2, max_evals=2, max_trials=10, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='hyperopt', trials_path='')
#
# Starting hyperopt
# HyperOpt batch size selected:32
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-15 22:00:55.096780: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-03-15 22:00:55.101943: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-03-15 22:00:55.102147: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x26ed100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 22:00:55.102180: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-15 22:00:55.103950: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-15 22:00:55.219547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:00:55.220126: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x26ed2c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-15 22:00:55.220157: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-03-15 22:00:55.220372: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:00:55.220712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:00:55.220992: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:00:55.222507: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:00:55.224016: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:00:55.224355: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:00:55.225777: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:00:55.226566: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:00:55.229849: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:00:55.229975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:00:55.230384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:00:55.230698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:00:55.230750: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:00:55.231827: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:00:55.231859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:00:55.231869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:00:55.231973: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:00:55.232366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:00:55.232720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-15 22:00:55.699649: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
#   0% 0/2 [00:05<?, ?it/s, best loss: ?]2020-03-15 22:00:58.210435: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:00:58.475108: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.834714
# accuracy: 0.195312
# ----1-----
# mean loss: 2.677958
# accuracy: 0.344727
# ----2-----
# mean loss: 2.241487
# accuracy: 0.415441
# ----3-----
# mean loss: 1.941584
# accuracy: 0.481934
# ----4-----
# mean loss: 1.812392
# accuracy: 0.496094
# ----0-----
# ----1-----
# eval mean loss: 1.516445
# eval accuracy: 0.583198
# eval avg class acc: 0.485363
# --- Total running time for EPOCH 000 : 0:02:02.744920 ---
# Model saved in file: log/hyperopttiny/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.581877
# accuracy: 0.544922
# ----1-----
# mean loss: 1.543116
# accuracy: 0.549805
# ----2-----
# mean loss: 1.509573
# accuracy: 0.577148
# ----3-----
# mean loss: 1.306405
# accuracy: 0.602328
# ----4-----
# mean loss: 1.349755
# accuracy: 0.599121
# ----0-----
# ----1-----
# eval mean loss: 1.553222
# eval accuracy: 0.551136
# eval avg class acc: 0.460763
# --- Total running time for EPOCH 001 : 0:01:59.886741 ---
# --- Total running time for MAIN : 0:04:08.401694 ---
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [04:08<04:08, 248.42s/it, best loss: 1.553222182509187]2020-03-15 22:05:02.887554: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:05:02.887980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:05:02.888090: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:05:02.888122: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:05:02.888164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:05:02.888190: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:05:02.888217: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:05:02.888243: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:05:02.888269: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:05:02.888387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:05:02.888793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:05:02.889135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:05:02.889302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:05:02.889323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:05:02.889338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:05:02.889461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:05:02.889866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:05:02.890204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 22:05:03.434652: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.842213
# accuracy: 0.168945
# ----1-----
# mean loss: 2.999244
# accuracy: 0.229980
# ----2-----
# mean loss: 2.654790
# accuracy: 0.305664
# ----3-----
# mean loss: 2.315587
# accuracy: 0.356934
# ----4-----
# mean loss: 2.125517
# accuracy: 0.391990
# ----0-----
# ----1-----
# eval mean loss: 1.896256
# eval accuracy: 0.397321
# eval avg class acc: 0.334679
# --- Total running time for EPOCH 000 : 0:01:59.068059 ---
# Model saved in file: log/hyperopttiny/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.056540
# accuracy: 0.402306
# ----1-----
# mean loss: 1.920315
# accuracy: 0.439941
# ----2-----
# mean loss: 1.776716
# accuracy: 0.478027
# ----3-----
# mean loss: 1.871702
# accuracy: 0.458984
# ----4-----
# mean loss: 1.817745
# accuracy: 0.468750
# ----0-----
# ----1-----
# eval mean loss: 1.392101
# eval accuracy: 0.614042
# eval avg class acc: 0.499591
# --- Total running time for EPOCH 001 : 0:01:57.482211 ---
# --- Total running time for MAIN : 0:04:01.270427 ---
# 100% 2/2 [08:09<00:00, 246.28s/it, best loss: 1.392101272360071]
# Run 1 - Best param found:{'batch_size': 3}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.553222182509187, 'status': 'ok', 'accuracy': 0.5511363636363636, 'avg_class_accuracy': 0.46076251480155134, 'eval_time': 1584309899.8022027, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 0, 51, 431000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 849000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.392101272360071, 'status': 'ok', 'accuracy': 0.6140422077922078, 'avg_class_accuracy': 0.499591350141184, 'eval_time': 1584310141.0841868, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 851000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 9, 1, 134000)}
# Written trials on run 1.
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-15 22:09:04.381246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:09:04.381629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:09:04.381731: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:09:04.381765: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:09:04.381791: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:09:04.381819: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:09:04.381843: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:09:04.381876: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:09:04.381902: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:09:04.381996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:09:04.382381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:09:04.382672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:09:04.382724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:09:04.382740: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:09:04.382754: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:09:04.382874: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:09:04.383227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:09:04.383543: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 22:09:04.929004: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.881322
# accuracy: 0.177791
# ----1-----
# mean loss: 2.890593
# accuracy: 0.269043
# ----2-----
# mean loss: 2.547389
# accuracy: 0.312988
# ----3-----
# mean loss: 2.318892
# accuracy: 0.359375
# ----4-----
# mean loss: 2.168590
# accuracy: 0.384766
# ----0-----
# ----1-----
# eval mean loss: 1.800664
# eval accuracy: 0.470373
# eval avg class acc: 0.364140
# --- Total running time for EPOCH 000 : 0:01:59.122687 ---
# Model saved in file: log/hyperopttiny/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.882227
# accuracy: 0.450195
# ----1-----
# mean loss: 1.797693
# accuracy: 0.485352
# ----2-----
# mean loss: 2.101023
# accuracy: 0.429199
# ----3-----
# mean loss: 1.738574
# accuracy: 0.487864
# ----4-----
# mean loss: 1.656763
# accuracy: 0.503418
# ----0-----
# ----1-----
# eval mean loss: 1.546652
# eval accuracy: 0.515828
# eval avg class acc: 0.434384
# --- Total running time for EPOCH 001 : 0:01:57.617800 ---
# --- Total running time for MAIN : 0:04:01.652831 ---
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [04:01<04:01, 241.67s/it, best loss: 1.392101272360071]2020-03-15 22:13:06.091967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:13:06.092363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:13:06.092473: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:13:06.092493: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:13:06.092507: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:13:06.092520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:13:06.092533: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:13:06.092545: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:13:06.092559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:13:06.092627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:13:06.092949: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:13:06.093208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:13:06.093246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:13:06.093256: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:13:06.093265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:13:06.093353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:13:06.093651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:13:06.093951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 22:13:06.748275: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.668679
# accuracy: 0.174805
# ----1-----
# mean loss: 2.992213
# accuracy: 0.230957
# ----2-----
# mean loss: 2.707281
# accuracy: 0.293457
# ----3-----
# mean loss: 2.460268
# accuracy: 0.339806
# ----4-----
# mean loss: 2.166756
# accuracy: 0.396484
# ----0-----
# ----1-----
# eval mean loss: 1.996873
# eval accuracy: 0.423295
# eval avg class acc: 0.342334
# --- Total running time for EPOCH 000 : 0:01:59.253232 ---
# Model saved in file: log/hyperopttiny/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.973496
# accuracy: 0.439453
# ----1-----
# mean loss: 1.898931
# accuracy: 0.457031
# ----2-----
# mean loss: 1.763992
# accuracy: 0.501820
# ----3-----
# mean loss: 1.625765
# accuracy: 0.523926
# ----4-----
# mean loss: 1.548219
# accuracy: 0.536133
# ----0-----
# ----1-----
# eval mean loss: 1.338340
# eval accuracy: 0.616071
# eval avg class acc: 0.528405
# --- Total running time for EPOCH 001 : 0:01:57.783528 ---
# --- Total running time for MAIN : 0:04:02.071407 ---
# 100% 2/2 [08:03<00:00, 241.79s/it, best loss: 1.3383403420448303]
# Run 2 - Best param found:{'batch_size': 3}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.553222182509187, 'status': 'ok', 'accuracy': 0.5511363636363636, 'avg_class_accuracy': 0.46076251480155134, 'eval_time': 1584309899.8022027, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 0, 51, 431000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 849000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.392101272360071, 'status': 'ok', 'accuracy': 0.6140422077922078, 'avg_class_accuracy': 0.499591350141184, 'eval_time': 1584310141.0841868, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 851000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 9, 1, 134000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.546651518190062, 'status': 'ok', 'accuracy': 0.515827922077922, 'avg_class_accuracy': 0.4343841775610879, 'eval_time': 1584310382.7736006, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 9, 1, 161000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 13, 2, 825000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.3383403420448303, 'status': 'ok', 'accuracy': 0.6160714285714286, 'avg_class_accuracy': 0.5284049320926398, 'eval_time': 1584310624.8623369, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 13, 2, 827000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 17, 4, 912000)}
# Written trials on run 2.
# HyperOpt batch size selected:2
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-15 22:17:07.984685: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:17:07.985164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:17:07.985314: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:17:07.985359: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:17:07.985379: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:17:07.985401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:17:07.985420: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:17:07.985462: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:17:07.985521: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:17:07.985615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:17:07.986067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:17:07.986396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:17:07.986455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:17:07.986473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:17:07.986489: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:17:07.986610: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:17:07.987114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:17:07.987607: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 22:17:08.582796: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 6.485279
# accuracy: 0.075684
# ----1-----
# mean loss: 4.356111
# accuracy: 0.092773
# ----2-----
# mean loss: 4.018248
# accuracy: 0.080566
# ----3-----
# mean loss: 3.721464
# accuracy: 0.079490
# ----4-----
# mean loss: 3.739275
# accuracy: 0.080566
# ----0-----
# ----1-----
# eval mean loss: 48.403275
# eval accuracy: 0.015802
# eval avg class acc: 0.012750
# --- Total running time for EPOCH 000 : 0:03:15.930700 ---
# Model saved in file: log/hyperopttiny/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.535354
# accuracy: 0.100098
# ----1-----
# mean loss: 3.453250
# accuracy: 0.114684
# ----2-----
# mean loss: 3.475880
# accuracy: 0.117188
# ----3-----
# mean loss: 3.475391
# accuracy: 0.119141
# ----4-----
# mean loss: 3.388357
# accuracy: 0.125000
# ----0-----
# ----1-----
# eval mean loss: 31991.578895
# eval accuracy: 0.032010
# eval avg class acc: 0.019750
# --- Total running time for EPOCH 001 : 0:03:13.559531 ---
# --- Total running time for MAIN : 0:06:34.204044 ---
# HyperOpt batch size selected:2
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [06:34<06:34, 394.22s/it, best loss: 1.3383403420448303]2020-03-15 22:23:42.278301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:23:42.278645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:23:42.278737: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:23:42.278755: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:23:42.278774: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:23:42.278789: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:23:42.278805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:23:42.278818: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:23:42.278831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:23:42.278905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:23:42.279208: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:23:42.279506: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:23:42.279613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:23:42.279625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:23:42.279633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:23:42.279725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:23:42.280040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:23:42.280324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 22:23:42.902573: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 6.450634
# accuracy: 0.084961
# ----1-----
# mean loss: 5.216948
# accuracy: 0.071289
# ----2-----
# mean loss: 3.970484
# accuracy: 0.085938
# ----3-----
# mean loss: 3.834783
# accuracy: 0.075684
# ----4-----
# mean loss: 3.927388
# accuracy: 0.076456
# ----0-----
# ----1-----
# eval mean loss: 3733907.204218
# eval accuracy: 0.049433
# eval avg class acc: 0.030500
# --- Total running time for EPOCH 000 : 0:03:11.330616 ---
# Model saved in file: log/hyperopttiny/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.532751
# accuracy: 0.099515
# ----1-----
# mean loss: 3.468795
# accuracy: 0.086914
# ----2-----
# mean loss: 3.444923
# accuracy: 0.091309
# ----3-----
# mean loss: 3.438572
# accuracy: 0.091797
# ----4-----
# mean loss: 3.427511
# accuracy: 0.083496
# ----0-----
# ----1-----
# eval mean loss: 186.754941
# eval accuracy: 0.036467
# eval avg class acc: 0.022500
# --- Total running time for EPOCH 001 : 0:03:10.310352 ---
# --- Total running time for MAIN : 0:06:26.419987 ---
# 100% 2/2 [13:00<00:00, 391.88s/it, best loss: 1.3383403420448303]
# Run 3 - Best param found:{'batch_size': 3}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.553222182509187, 'status': 'ok', 'accuracy': 0.5511363636363636, 'avg_class_accuracy': 0.46076251480155134, 'eval_time': 1584309899.8022027, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 0, 51, 431000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 849000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.392101272360071, 'status': 'ok', 'accuracy': 0.6140422077922078, 'avg_class_accuracy': 0.499591350141184, 'eval_time': 1584310141.0841868, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 851000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 9, 1, 134000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.546651518190062, 'status': 'ok', 'accuracy': 0.515827922077922, 'avg_class_accuracy': 0.4343841775610879, 'eval_time': 1584310382.7736006, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 9, 1, 161000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 13, 2, 825000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.3383403420448303, 'status': 'ok', 'accuracy': 0.6160714285714286, 'avg_class_accuracy': 0.5284049320926398, 'eval_time': 1584310624.8623369, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 13, 2, 827000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 17, 4, 912000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 31991.578894721053, 'status': 'ok', 'accuracy': 0.0320097244732577, 'avg_class_accuracy': 0.01975, 'eval_time': 1584311019.2258165, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [4]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 17, 5, 56000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 23, 39, 272000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 186.75494073140564, 'status': 'ok', 'accuracy': 0.03646677471636953, 'avg_class_accuracy': 0.0225, 'eval_time': 1584311405.6559718, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [5]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 23, 39, 274000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 30, 5, 705000)}
# Written trials on run 3.
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-15 22:30:08.599803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:30:08.600172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:30:08.600263: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:30:08.600312: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:30:08.600337: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:30:08.600360: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:30:08.600379: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:30:08.600398: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:30:08.600438: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:30:08.600530: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:30:08.600866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:30:08.601147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:30:08.601193: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:30:08.601207: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:30:08.601216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# ...
# 2020-03-15 22:43:18.735617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:43:18.735709: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:43:18.735733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:43:18.735756: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:43:18.735778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:43:18.735803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:43:18.735828: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:43:18.735848: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:43:18.735929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:43:18.736254: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:43:18.736546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:43:18.736591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:43:18.736604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:43:18.736613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:43:18.736700: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:43:18.737027: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:43:18.737333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 22:43:19.459995: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.666586
# accuracy: 0.194336
# ----1-----
# mean loss: 2.893048
# accuracy: 0.269531
# ----2-----
# mean loss: 2.660297
# accuracy: 0.320388
# ----3-----
# mean loss: 2.407681
# accuracy: 0.360352
# ----4-----
# mean loss: 2.179076
# accuracy: 0.392090
# ----0-----
# ----1-----
# eval mean loss: 1.988020
# eval accuracy: 0.454951
# eval avg class acc: 0.356487
# --- Total running time for EPOCH 000 : 0:01:59.507148 ---
# Model saved in file: log/hyperopttiny/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.977805
# accuracy: 0.432129
# ----1-----
# mean loss: 1.832503
# accuracy: 0.472656
# ----2-----
# mean loss: 1.749042
# accuracy: 0.479004
# ----3-----
# mean loss: 1.678526
# accuracy: 0.496966
# ----4-----
# mean loss: 1.637954
# accuracy: 0.516602
# ----0-----
# ----1-----
# eval mean loss: 1.563220
# eval accuracy: 0.596591
# eval avg class acc: 0.506190
# --- Total running time for EPOCH 001 : 0:01:57.728991 ---
# --- Total running time for MAIN : 0:04:01.948109 ---
# 100% 2/2 [08:09<00:00, 245.53s/it, best loss: 1.124703269500237]
# Run 5 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.553222182509187, 'status': 'ok', 'accuracy': 0.5511363636363636, 'avg_class_accuracy': 0.46076251480155134, 'eval_time': 1584309899.8022027, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 0, 51, 431000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 849000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.392101272360071, 'status': 'ok', 'accuracy': 0.6140422077922078, 'avg_class_accuracy': 0.499591350141184, 'eval_time': 1584310141.0841868, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 4, 59, 851000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 9, 1, 134000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.546651518190062, 'status': 'ok', 'accuracy': 0.515827922077922, 'avg_class_accuracy': 0.4343841775610879, 'eval_time': 1584310382.7736006, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 9, 1, 161000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 13, 2, 825000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.3383403420448303, 'status': 'ok', 'accuracy': 0.6160714285714286, 'avg_class_accuracy': 0.5284049320926398, 'eval_time': 1584310624.8623369, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 13, 2, 827000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 17, 4, 912000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 31991.578894721053, 'status': 'ok', 'accuracy': 0.0320097244732577, 'avg_class_accuracy': 0.01975, 'eval_time': 1584311019.2258165, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [4]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 17, 5, 56000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 23, 39, 272000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 186.75494073140564, 'status': 'ok', 'accuracy': 0.03646677471636953, 'avg_class_accuracy': 0.0225, 'eval_time': 1584311405.6559718, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [5]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 23, 39, 274000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 30, 5, 705000)}
# {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': 1.4615140739199404, 'status': 'ok', 'accuracy': 0.5685876623376623, 'avg_class_accuracy': 0.4507871429050831, 'eval_time': 1584311647.3557174, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [6]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 30, 5, 725000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 34, 7, 407000)}
# {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': 2.951433012898969, 'status': 'ok', 'accuracy': 0.21758508914100486, 'avg_class_accuracy': 0.14625, 'eval_time': 1584311948.81288, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [7]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 34, 7, 408000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 39, 8, 861000)}
# {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': 1.124703269500237, 'status': 'ok', 'accuracy': 0.6724837662337663, 'avg_class_accuracy': 0.5917783386786709, 'eval_time': 1584312195.8907812, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [8]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 39, 8, 883000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 43, 15, 944000)}
# {'state': 2, 'tid': 9, 'spec': None, 'result': {'loss': 1.5632200109494196, 'status': 'ok', 'accuracy': 0.5965909090909091, 'avg_class_accuracy': 0.5061899092970521, 'eval_time': 1584312437.8524609, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 9, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [9]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 15, 22, 43, 15, 945000), 'refresh_time': datetime.datetime(2020, 3, 15, 22, 47, 17, 904000)}
# Written trials on run 5.
# HyperOpt batch size selected:4
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-15 22:47:21.003852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:47:21.004247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-15 22:47:21.004363: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-15 22:47:21.004395: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-15 22:47:21.004413: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-15 22:47:21.004430: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-15 22:47:21.004447: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-15 22:47:21.004463: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-15 22:47:21.004481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-15 22:47:21.004556: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:47:21.004890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:47:21.005162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-15 22:47:21.005204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-15 22:47:21.005217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-15 22:47:21.005230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-15 22:47:21.005326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:47:21.005641: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-15 22:47:21.005933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# 2020-03-15 22:47:21.761788: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 4.096022
# accuracy: 0.094727
# ----1-----
# mean loss: 3.622554
# accuracy: 0.110437
# ----2-----
# mean loss: 3.530928
# accuracy: 0.102051
# ----3-----
#   0% 0/2 [01:25<?, ?it/s, best loss: ?]

# %%
import os
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet/')

#second run since first run was interrupted at EPOCH 119
# !python train.py --max_epoch=2 --run_mode='hyperopt' --log_dir="log/hyperopttiny" --max_eval=2  # --batch_size=16 #--log_dir="log"

# %%
import os
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet/')

# !python evaluate.py 
#--model_path="log/normal5/model.ckpt"

# %% [markdown]
# ## Running tensorboard with the pointnet result
# https://www.dlology.com/blog/quick-guide-to-run-tensorboard-in-google-colab/

# %%
str = ""
if str:
  print ("not empty")

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
os.chdir('/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet')

LOG_DIR = './log/11'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# ## Running pointnet 2

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2/tf_ops/sampling')
# !bash tf_sampling_compile.sh

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2/tf_ops/grouping')
# !bash tf_grouping_compile.sh

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2/tf_ops/3d_interpolation')
# !bash tf_interpolate_compile.sh

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2')

# !python train.py #--gpu 0 # train_multi_gpu.py #--num_gpu=8

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2')

# !python evaluate.py

# %% [markdown]
# ## Running tensorboard with the pointnet 2 result
# https://www.dlology.com/blog/quick-guide-to-run-tensorboard-in-google-colab/

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2')
os.chdir('/content/gdrive/My Drive/GitHub/PointnetEnhanced/pointnet2/pointnet2')

LOG_DIR = './log'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6007 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6007 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# ## Running 3DmFV-Net
#
# Mount the google drive and point to the folder containing the train.py and run the code from there with a slight modification.

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/3DmFV-Net-master')
#os.chdir('/content/gdrive/My Drive/GitHub/PointnetEnhanced/pointnet/')


# !python train_cls.py --gpu=0 #--batch_size=128
